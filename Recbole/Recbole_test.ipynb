# %%
import os
import json
import argparse
import pandas as pd
import numpy as np
import time, datetime
from tqdm import tqdm
from logging import getLogger
import torch

from recbole.model.general_recommender.multivae import MultiVAE
from recbole.quick_start import run_recbole

from recbole.config import Config
from recbole.data import dataset
from recbole.data import create_dataset, data_preparation, Interaction
from recbole.utils import init_logger, get_trainer, get_model, init_seed, set_color


SEED=13

# %% [markdown]
# # 데이터 불러오기

# %%
def run(model_name):

    return run_recbole(
        model=model_name,
        dataset='train_data',
        config_file_list=['/opt/ml/wine/Recbole/general.yaml'],
    )

# %%
from recbole.config import Config
config_file_list=['/opt/ml/wine/Recbole/general.yaml']
model='DCN'
dataset='train_data'
config = Config(model=model, dataset=dataset, config_file_list=config_file_list)
dataset = create_dataset(config)

# %%
train_data, valid_data, test_data = data_preparation(config, dataset)

# %%
for batch_idx, interaction in enumerate(train_data):    
    break

# %%
dataset.field2token_id['grape']
# Out:
# {'[PAD]': 0,
#  'Merlot': 1,
#  'CabernetSauvignon': 2,
#  'CabernetFranc': 3,
#  'MoscatoBianco': 4,
#  'Gamay': 5,
#  'PinotGris': 6,
#  'Chardonnay': 7,
#  'PinotNoir': 8,
#  'PinotMeunier': 9,
#  'Shiraz/Syrah': 10,
#  'CheninBlanc': 11,
#  'Tempranillo': 12,
#  'PetitManseng': 13,
#  'Sylvaner': 14,
#  'TintaBarroca': 15,
#  'Mencia': 16,
#  'Riesling': 17,
#  'Tibouren': 18,
#  'Empty': 19,
#  'Sangiovese': 20,
#  'TourigaNacional': 21,
#  'Malbec': 22,
#  'PetitVerdot': 23,
#  'Dafni': 24,
#  'TintaRoriz': 25,
#  'TourigaFrancesa': 26,
#  '588': 27,
#  'Traminer': 28,
#  'Corvina': 29,
#  'Rondinella': 30,
#  'Molinara': 31,
#  'Grenache': 32,
#  "Nerod'Avola": 33,
#  'Mammolo': 34,
#  'GrünerVeltliner': 35,
#  'Mourvedre': 36,
#  'Teroldego': 37,
#  'Carignan': 38,
#  'Cinsault': 39,
#  'Aglianico': 40,
#  'Turbiana': 41,
#  'Friulano': 42,
#  'Monastrell': 43,
#  'Nebbiolo': 44,
#  'SauvignonBlanc': 45,
#  'Sémillon': 46,
#  'Palomino': 47,
#  'GrenacheBlanc': 48,
#  'Clairette': 49,
#  'PicpoulBlanc': 50,
#  'Garnacha': 51,
#  'Barbera': 52,
#  'Alvarinho': 53,
#  'Caprettone': 54,
#  'TocaiFriulano': 55,
#  'PinotGrigio': 56,
#  'TintoFino': 57,
#  'Freisa': 58,
#  'Vermentino': 59,
#  'Macabeo': 60,
#  'Montepulciano': 61,
#  'MelondeBourgogne': 62,
#  'NerelloMascalese': 63,
#  'Mataro': 64,
#  'RibollaGialla': 65,
#  'Picolit': 66,
#  'Verduzzo': 67,
#  'Parellada': 68,
#  'Corvinone': 69,
#  'Vernatsch': 70,
#  'Moscato': 71,
#  'Roussanne': 72,
#  'Zinfandel': 73,
#  'PetiteSirah': 74,
#  'Muscadelle': 75,
#  'GarnachaTintorera': 76,
#  'Carménère': 77,
#  '1670': 78,
#  'Ramisco': 79,
#  'Assyrtiko': 80,
#  'Agiorgitiko': 81,
#  'PinotBlanc': 82,
#  'HondarrabiZuri': 83,
#  'Malvasia': 84,
#  'Oseleta': 85,
#  'Pinotage': 86,
#  'Trebbiano': 87,
#  'PinotNero': 88,
#  'Xinomavro': 89,
#  'Bellone': 90,
#  'Bourboulenc': 91,
#  'Glera': 92,
#  'PetitCourbu': 93,
#  'Procanico': 94,
#  'Greco': 95,
#  'Aligoté': 96,
#  'Limniona': 97,
#  '1153': 98,
#  'Poulsard': 99,
#  'Verdejo': 100,
#  'Spätburgunder': 101,
#  'Albariño': 102,
#  'Falanghina': 103,
#  'Counoise': 104,
#  'Öküzgözü': 105,
#  'Grolleau': 106,
#  'Negrette': 107,
#  'AlicanteBouschet': 108,
#  '562': 109,
#  'Fumin': 110,
#  'VernacciadiSanGimignano': 111,
#  'MalvasiaNera': 112,
#  'Rabigato': 113,
#  'Viosinho': 114,
#  'GrosManseng': 115,
#  'Frappato': 116,
#  'Cortese': 117,
#  'Ugniblanc': 118,
#  '1719': 119,
#  'Verdeca': 120,
#  'Rossese': 121,
#  'Zweigelt': 122,
#  'Viognier': 123,
#  'Marsanne': 124,
#  'Blaufränkisch': 125,
#  'Arneis': 126,
#  'CorvinaVeronese': 127,
#  'Verdelho': 128,
#  'Xarel-lo': 129,
#  'Refosco': 130,
#  'Croatina': 131,
#  'Malagouzia': 132,
#  '883': 133,
#  'TintaFrancisca': 134,
#  'MuscatBlanc': 135,
#  'Pigato': 136,
#  'Altesse': 137,
#  'Cariñena': 138,
#  'OrangeMuscat': 139,
#  'Mazuelo': 140,
#  'Grauburgunder': 141,
#  'GarnachaBlanca': 142,
#  'CanaioloNero': 143,
#  'Valdiguie': 144,
#  'Primitivo': 145,
#  'Garganega': 146,
#  'Mavrotragano': 147,
#  'Pecorino': 148,
#  'Dolcetto': 149,
#  'Chasselas': 150,
#  'Tannat': 151,
#  'Savagnin': 152,
#  'TintadelPais': 153,
#  '514': 154,
#  'Prokupac': 155,
#  'Voskeat': 156,
#  'Grillo': 157,
#  'Sciacarello': 158,
#  '633': 159,
#  'Sagrantino': 160,
#  'Weissburgunder': 161,
#  'Brachetto': 162,
#  'Catawba': 163,
#  'Gewürztraminer': 164,
#  'Melnik': 165,
#  'Moscatel': 166,
#  'Baga': 167,
#  'Vernaccia': 168,
#  'Nosiola': 169,
#  'Graciano': 170,
#  'Kerner': 171,
#  'Aragonez': 172,
#  'CatarrattoBianco': 173,
#  'Morellino': 174,
#  'Welschriesling': 175,
#  'Colombard': 176,
#  '1716': 177,
#  'GarnachaTinta': 178,
#  'Verdicchio': 179,
#  'Picardan': 180,
#  'Schioppettino': 181,
#  'TourigaFranca': 182,
#  'Sercial': 183,
#  'Loureiro': 184,
#  'TintoCao': 185,
#  'Groppello': 186,
#  'Trousseau': 187,
#  'Timorasso': 188,
#  '1349': 189,
#  '404': 190,
#  'Vinhão': 191,
#  '1556': 192,
#  'Souzao': 193,
#  'MuscatofAlexandria': 194,
#  'Sercialinho': 195,
#  'Castelao': 196,
#  'NerelloCappuccio': 197,
#  'Grecanico': 198,
#  'Carricante': 199,
#  '1221': 200,
#  'Malvar': 201,
#  'Dornfelder': 202,
#  'Godello': 203,
#  'Torrontés': 204,
#  '620': 205,
#  'Glera(Prosecco)': 206,
#  'Fiano': 207,
#  '678': 208,
#  'Grechetto': 209,
#  'MondeuseNoire': 210,
#  'Scheurebe': 211,
#  'Neuburger': 212,
#  'Rotgipfler': 213,
#  'Zierfandler': 214,
#  '636': 215,
#  '639': 216,
#  'Müller-Thurgau': 217,
#  'Pignolo': 218,
#  'Lagrein': 219,
#  'Moreto': 220,
#  '579': 221,
#  'Pais': 222,
#  'Lambrusco': 223,
#  '583': 224,
#  '1692': 225,
#  '663': 226,
#  '1657': 227,
#  '1673': 228,
#  'GelberMuskateller': 229,
#  'SauvignonGris': 230,
#  'CayugaWhite': 231,
#  'Blauburgunder': 232,
#  'MoscateldeAlejandría': 233,
#  '564': 234,
#  'Mavrodafni': 235,
#  '677': 236,
#  '1539': 237,
#  'Elbling': 238,
#  'PedroXimenez': 239,
#  'Erbaluce': 240,
#  'Monemvassia': 241,
#  'Moschofilero': 242,
#  'Saperavi': 243,
#  'TintaAmarela': 244,
#  "PineauD'Aunis": 245,
#  'Bonarda': 246,
#  'TintaNegraMole': 247,
#  '1421': 248,
#  'Favorita': 249,
#  'Nasco': 250,
#  'GrenacheGris': 251,
#  'Roscetto': 252,
#  '1123': 253,
#  '1515': 254,
#  'YellowMuscat': 255,
#  'Pugnitello': 256,
#  'Furmint': 257,
#  'Piedirosso': 258,
#  'ManzoniBianco': 259,
#  'Gouveio': 260,
#  'Viura': 261,
#  'Albanella': 262,
#  'UvaRara': 263,
#  'Jacquère': 264,
#  'Rkatsiteli': 265,
#  '1255': 266,
#  'Nuragus': 267,
#  '704': 268,
#  '1256': 269,
#  '698': 270,
#  '702': 271,
#  'Negroamaro': 272,
#  '1014': 273,
#  '1416': 274,
#  '966': 275,
#  'AlbilloMayor': 276,
#  'Caiñotinto': 277,
#  'AlfrocheiroPreto': 278,
#  'Jaen': 279,
#  'Tintadetoro': 280,
#  'St.Laurent': 281,
#  'Robola': 282,
#  'PrugnoloGentile': 283,
#  '1391': 284,
#  'Cannonau': 285,
#  '550': 286,
#  '1589': 287,
#  'RefoscodalPeduncolorosso': 288,
#  'Bical': 289,
#  'Roesler': 290,
#  'Inzolia': 291,
#  'MuscatOttonel': 292,
#  'ArintodeBucelas': 293,
#  'Trajadura': 294,
#  'Samsó': 295,
#  '494': 296,
#  '648': 297,
#  'BianchettaTrevigiana': 298,
#  'Auxerrois': 299,
#  'Calkarasi': 300,
#  'Gaglioppo': 301,
#  'Concord': 302,
#  'Ciliegiolo': 303,
#  'Kékfrankos': 304,
#  'Savatiano': 305,
#  '887': 306,
#  'Rufete': 307,
#  '1671': 308,
#  'Cesanese': 309,
#  '1374': 310,
#  'Vidal': 311,
#  '614': 312,
#  '1042': 313,
#  '625': 314,
#  'Vitovska': 315,
#  'Narince': 316,
#  '1336': 317,
#  'Manseng': 318,
#  "Biancod'Alessano": 319,
#  '1222': 320,
#  'Charbono': 321,
#  '434': 322,
#  '444': 323,
#  '619': 324,
#  'GamayNoir': 325,
#  'MauzacBlanc': 326,
#  'Nascetta': 327,
#  '1697': 328,
#  'BlackMuscat': 329,
#  'FernaoPires': 330,
#  'Ancellotta': 331,
#  'Bobal': 332,
#  'PetiteArvine': 333,
#  'MalvasiaFina': 334,
#  'Abouriou': 335,
#  'CodadiVolpeBiancha': 336,
#  'Malmsey': 337,
#  'Aleatico': 338,
#  '571': 339,
#  'Trincadeira': 340,
#  '682': 341,
#  '895': 342,
#  '1212': 343,
#  'FerServadou': 344,
#  'RoterVeltliner': 345,
#  '1293': 346,
#  'Grignolino': 347,
#  'Silvaner': 348,
#  'Merseguera': 349,
#  '1701': 350,
#  'Muscatel': 351,
#  '1554': 352,
#  '569': 353,
#  'Ruché': 354,
#  'PrietoPicudo': 355,
#  '1730': 356,
#  '1632': 357,
#  'Zibibbo': 358,
#  '642': 359,
#  'Torbato': 360,
#  'ListanNegro': 361,
#  '454': 362,
#  '597': 363,
#  'Susumaniello': 364,
#  '1519': 365,
#  'Caberlot': 366,
#  'Tintilia': 367,
#  '546': 368,
#  'MoscatoGiallo': 369,
#  'Symphony': 370,
#  '1136': 371,
#  '885': 372,
#  '1177': 373,
#  'Albana': 374,
#  'Encruzado': 375,
#  '524': 376,
#  'Cencibel': 377,
#  'Caladoc': 378,
#  'Cinsaut': 379,
#  '534': 380,
#  'Ansonica': 381,
#  'TempranilloBlanco': 382,
#  'PinotBianco': 383,
#  'GrecoBianco': 384,
#  'Mandilaria': 385,
#  'Marmajuelo': 386,
#  'Vidiano': 387,
#  'Marzemino': 388,
#  'Trepat': 389,
#  'Callet': 390,
#  'Durif': 391,
#  'BiancuGentile': 392,
#  'Schiava': 393,
#  '675': 394,
#  'Parraleta': 395,
#  'CalabresediMontenuovo': 396,
#  'Vespolina': 397,
#  'Hárslevelű': 398,
#  'NerodiTroia': 399,
#  '557': 400,
#  'Frontenac': 401,
#  'Romorantin': 402,
#  'MuscatdeFrontignan': 403,
#  'TintaMadeira': 404,
#  '1739': 405,
#  'PallagrelloNero': 406,
#  '1086': 407,
#  'Tazzelenghe': 408,
#  'MavroKalavritino': 409,
#  'Moscateldegranomenudo': 410,
#  "TrebbianoD'Abruzzo": 411,
#  '780': 412,
#  '1688': 413,
#  'RabosoPiave': 414,
#  'ColorinodelValdarno': 415,
#  '1253': 416,
#  'TintoVelasco': 417,
#  'AntãoVaz': 418,
#  'Terrantez': 419,
#  '1196': 420,
#  'Juhfark': 421,
#  '1372': 422,
#  '829': 423,
#  'Albillo': 424,
#  '589': 425,
#  'SauvignonMusque': 426,
#  '1011': 427,
#  '1178': 428,
#  'Prié': 429,
#  'Mission': 430,
#  '1552': 431,
#  'Skrlet': 432,
#  'PiquepoulBlanc': 433,
#  '628': 434,
#  '653': 435,
#  '646': 436,
#  '647': 437,
#  '1483': 438,
#  'MalvasiadiCandiaAromatica': 439,
#  '862': 440,
#  'FogliaTonda': 441,
#  '1974': 442,
#  'AlbarinBlanco': 443,
#  '1156': 444,
#  '548': 445,
#  '732': 446,
#  'Rolle': 447,
#  'Macertino': 448,
#  '595': 449,
#  'FolleBlanche': 450,
#  '1639': 451,
#  'Terrano': 452,
#  'Aidani': 453,
#  '464': 454,
#  'Sumoll': 455,
#  'Vilana': 456,
#  'Treixadura': 457,
#  'Roupeiro': 458,
#  '504': 459,
#  '573': 460,
#  'BlauerWildbacher': 461,
#  'PlavacMali': 462,
#  '1338': 463,
#  '634': 464,
#  '635': 465,
#  '1622': 466,
#  'Szürkebarát': 467,
#  '676': 468,
#  '1105': 469,
#  '1151': 470,
#  'Vranac': 471,
#  '1599': 472,
#  'Bual': 473,
#  '793': 474,
#  '758': 475,
#  '1603': 476,
#  '593': 477,
#  '551': 478,
#  '556': 479,
#  '1078': 480,
#  'GoruliMtsvane': 481,
#  '1154': 482,
#  '1200': 483,
#  'Cococciola': 484,
#  'Lacrima': 485,
#  'CorvinaGrossa': 486,
#  'Pelaverga': 487,
#  'Tamarez': 488,
#  'MariaGomes': 489,
#  'Monica': 490,
#  '643': 491,
#  '664': 492,
#  'Niagara': 493,
#  '957': 494,
#  'UvadiTroia': 495,
#  '1689': 496,
#  'Pignoletto': 497,
#  'Lemberger': 498,
#  'CriollaGrande': 499,
#  '599': 500,
#  'MuscatBlancàPetitsGrains': 501,
#  '1680': 502,
#  'Pederna': 503,
#  'Marselan': 504,
#  'Alvarelhao': 505,
#  '604': 506,
#  '1231': 507,
#  'AzalBranco': 508,
#  'MalvazijaIstarska': 509,
#  '1157': 510,
#  '671': 511,
#  '1190': 512,
#  '616': 513,
#  '1182': 514,
#  '1710': 515,
#  'Kotsifali': 516,
#  'Burgund': 517,
#  '1175': 518,
#  '580': 519,
#  'MaglioccoCanino': 520,
#  'RieslingRenano': 521,
#  'Côt': 522,
#  'RubyCabernet': 523,
#  'Dindarella': 524,
#  'CabernetBlanc': 525,
#  'Famoso': 526,
#  'FuméBlanc': 527,
#  '750': 528,
#  '1529': 529,
#  '553': 530,
#  'TintaMiuda': 531,
#  '1265': 532,
#  '587': 533,
#  'Rieslaner': 534,
#  'Babic': 535,
#  'Limnio': 536,
#  'Areni': 537,
#  'Thrapsathiri': 538,
#  'BoalBranco': 539,
#  'Nielluccio': 540,
#  'Liatiko': 541,
#  'Negramoll': 542,
#  'VidalBlanc': 543,
#  'CorintoNero': 544,
#  'Catalanesca': 545,
#  '1232': 546,
#  'Soave': 547,
#  'MoscateldeSetúbal': 548,
#  '1030': 549,
#  '1918': 550,
#  '1962': 551,
#  'AlbillodeAlbacete': 552,
#  'BombinoBianco': 553,
#  'CanaioloBlanco': 554,
#  '1733': 555,
#  'BombinoNero': 556,
#  'Grasevina': 557,
#  'MoscatoRosadelTrentino': 558,
#  'Biancolella': 559,
#  'Sárgamuskotály': 560,
#  'Verdesse': 561,
#  'Isabella': 562,
#  'Rhoditis': 563,
#  '584': 564,
#  'Flora': 565,
#  'MoscatelGalego': 566,
#  'Norton': 567,
#  '1070': 568,
#  'PetitRouge': 569,
#  '1687': 570,
#  '889': 571,
#  '576': 572,
#  'Rivaner': 573,
#  '1282': 574,
#  'Acolon': 575,
#  'Bukettraube': 576,
#  'Xynisteri': 577,
#  'ArintodosAçores': 578,
#  'Minutolo': 579,
#  '565': 580,
#  '1355': 581,
#  '1180': 582,
#  '1350': 583,
#  '1789': 584,
#  '1686': 585,
#  'DonzelinhoBranco': 586,
#  'Ortrugo': 587,
#  '1101': 588,
#  '1330': 589,
#  'TrebbianoGiallo': 590,
#  '1624': 591,
#  '1321': 592,
#  '839': 593,
#  '1665': 594,
#  '609': 595,
#  'PosipBijeli': 596,
#  'Kangun': 597,
#  '1032': 598,
#  '1184': 599,
#  'Gringet': 600,
#  '938': 601,
#  'Perricone': 602,
#  '1202': 603,
#  '601': 604,
#  'Persan': 605,
#  'Chambourcin': 606,
#  '715': 607,
#  '611': 608,
#  'PallagrelloBianco': 609,
#  '975': 610,
#  '623': 611,
#  '1520': 612,
#  'TrebbianoRomagnolo': 613,
#  'RavatBlanc': 614,
#  '1813': 615,
#  '1034': 616,
#  '1631': 617,
#  'Fragolino': 618,
#  '1790': 619,
#  'Tsolikouri': 620,
#  'Drupeggio': 621,
#  'CaiñoBlanco': 622,
#  '568': 623,
#  'Centesiminio': 624,
#  'Zametovka': 625,
#  '1675': 626,
#  'TrebbianoSpoletino': 627,
#  '1641': 628,
#  '1566': 629,
#  '1565': 630,
#  'Rubired': 631,
#  'Vignoles': 632,
#  'MinellaBianca': 633,
#  'Vijiriega': 634,
#  'BlauerPortugieser': 635,
#  '927': 636,
#  'Lumassina': 637,
#  'TrebbianoToscano': 638,
#  'BacoNoir': 639,
#  'MuscatHamburg': 640,
#  '1026': 641,
#  '1419': 642,
#  '1616': 643,
#  'Kratosija': 644,
#  'Muscadine': 645,
#  'Carrasquin': 646,
#  '608': 647,
#  'Gutedel': 648,
#  'IncrocioManzoni': 649,
#  '630': 650,
#  'DoñaBlanca': 651,
#  'Avgoustiatis': 652,
#  'Ortega': 653,
#  'Kadarka': 654,
#  'Passerina': 655,
#  'Espadeiro': 656,
#  'Sciascinoso': 657,
#  '474': 658,
#  'RabodeOvelha': 659,
#  'Debina': 660,
#  '610': 661,
#  '977': 662,
#  'Pelavergapiccolo': 663,
#  'Girò': 664,
#  '1334': 665,
#  '892': 666,
#  '1295': 667,
#  '1191': 668,
#  'Cynthiana': 669,
#  'Negoska': 670,
#  '1281': 671,
#  '1720': 672,
#  'MoscatelRoxo': 673,
#  'Bacchus': 674,
#  'Airen': 675,
#  'MantonicoBianco': 676,
#  'MuscatNoir': 677,
#  'Bovale': 678,
#  'Fortana': 679,
#  'NegraraTrentino': 680,
#  '837': 681,
#  '1185': 682,
#  'VernacciadiOristano': 683,
#  '1640': 684,
#  '2271': 685,
#  'Trollinger': 686,
#  'Obaideh': 687,
#  'PlantaNova': 688,
#  '1003': 689,
#  '1607': 690,
#  'UlldeLlebre': 691,
#  '674': 692,
#  '673': 693,
#  'BăbeascăNeagră': 694,
#  'ListanPrieto': 695,
#  'Ives': 696,
#  '547': 697,
#  'Baratuciat': 698,
#  'Karmahyut': 699,
#  'MisketCherven': 700,
#  'CesanesediAffile': 701,
#  '1691': 702,
#  '1619': 703,
#  'NeroBuonodiCori': 704,
#  '978': 705,
#  'Melon': 706,
#  '1602': 707,
#  '1074': 708,
#  '662': 709,
#  '1711': 710,
#  'VermentinoNero': 711,
#  '760': 712,
#  '1423': 713,
#  '714': 714,
#  'Plyto': 715,
#  '1258': 716,
#  '554': 717,
#  '1033': 718,
#  'ManzoniMoscato': 719,
#  'Avesso': 720,
#  '1367': 721,
#  'Plavina': 722,
#  '1714': 723,
#  '684': 724,
#  'CabernetDorsa': 725,
#  '1266': 726,
#  '590': 727,
#  '1076': 728,
#  'Pinella': 729,
#  'BéquignolNoir': 730,
#  'Biancame': 731,
#  '1433': 732,
#  '559': 733,
#  'Mavrud': 734,
#  '928': 735,
#  'Verdiso': 736,
#  'Sauvignonasse': 737,
#  'Mavrokoudoura': 738,
#  '1858': 739,
#  'TintilladeRota': 740,
#  '950': 741,
#  '1261': 742,
#  '656': 743,
#  '915': 744,
#  '1179': 745,
#  'MalvasiadiSchierano': 746,
#  '1477': 747,
#  '1702': 748,
#  '1005': 749,
#  'Maratheftiko': 750,
#  'Spergola': 751,
#  '572': 752,
#  'Nocera': 753,
#  'Cornalin': 754,
#  '414': 755,
#  '728': 756,
#  'Pinenc': 757,
#  'Moschomavro': 758,
#  'Lado': 759,
#  'LledonerPelut': 760,
#  'Ondenc': 761,
#  'Orangetraube': 762,
#  '585': 763,
#  '602': 764,
#  'Albarossa': 765,
#  '1243': 766,
#  '1370': 767,
#  '1594': 768,
#  'Fogoney': 769,
#  'MaglioccoDolce': 770,
#  'Peloursin': 771,
#  'Grk': 772,
#  'VerduzzoFriulano': 773,
#  'Forastera': 774,
#  'CercealBranco': 775,
#  '1304': 776,
#  '1721': 777,
#  'Dureza': 778,
#  'Vincent': 779,
#  'Cagnulari': 780,
#  'Rubin': 781,
#  '1695': 782,
#  '851': 783,
#  '1238': 784,
#  '1331': 785,
#  "Moore'sDiamond": 786,
#  '1233': 787,
#  'Vuillermin': 788,
#  '1027': 789,
#  'Arinarnoa': 790,
#  '1596': 791,
#  '693': 792,
#  'FeteascaRegala': 793,
#  'RabosoVeronese': 794,
#  '1642': 795,
#  'SeyvalBlanc': 796,
#  'TrincadeiradasPratas': 797,
#  '1250': 798,
#  '1474': 799,
#  '748': 800,
#  '818': 801,
#  '749': 802,
#  'DoronadiVenezia': 803,
#  'MenuPineau': 804}

# %%
interaction
# Out:
# The batch_size of interaction: 1024
#     user_id, torch.Size([1024]), cpu, torch.int64
#     item_id, torch.Size([1024]), cpu, torch.int64
#     label, torch.Size([1024]), cpu, torch.float32
#     count, torch.Size([1024]), cpu, torch.float32
#     mean, torch.Size([1024]), cpu, torch.float32
#     country, torch.Size([1024]), cpu, torch.int64
#     region, torch.Size([1024]), cpu, torch.int64
#     winery, torch.Size([1024]), cpu, torch.int64
#     winetype, torch.Size([1024]), cpu, torch.int64
#     grape, torch.Size([1024, 15]), cpu, torch.int64
#     vintage, torch.Size([1024]), cpu, torch.int64
#     price, torch.Size([1024]), cpu, torch.float32
#     rating, torch.Size([1024]), cpu, torch.float32
#     num_votes, torch.Size([1024]), cpu, torch.float32
#     wine_style, torch.Size([1024]), cpu, torch.int64
#     Red Fruit_count, torch.Size([1024]), cpu, torch.float32
#     Tropical_count, torch.Size([1024]), cpu, torch.float32
#     Tree Fruit_count, torch.Size([1024]), cpu, torch.float32
#     Oaky_count, torch.Size([1024]), cpu, torch.float32
#     Ageing_count, torch.Size([1024]), cpu, torch.float32
#     Black Fruit_count, torch.Size([1024]), cpu, torch.float32
#     Citrus_count, torch.Size([1024]), cpu, torch.float32
#     Dried Fruit_count, torch.Size([1024]), cpu, torch.float32
#     Earthy_count, torch.Size([1024]), cpu, torch.float32
#     Floral_count, torch.Size([1024]), cpu, torch.float32
#     Microbio_count, torch.Size([1024]), cpu, torch.float32
#     Spices_count, torch.Size([1024]), cpu, torch.float32
#     Vegetal_count, torch.Size([1024]), cpu, torch.float32

# %%
interaction['grape']
# Out:
# tensor([[ 1,  2,  3,  ...,  0,  0,  0],
#         [ 2,  1,  0,  ...,  0,  0,  0],
#         [ 1,  2,  3,  ...,  0,  0,  0],
#         ...,
#         [ 2,  0,  0,  ...,  0,  0,  0],
#         [12,  0,  0,  ...,  0,  0,  0],
#         [ 2,  0,  0,  ...,  0,  0,  0]])

# %%
dataset.field2token_id

# %%
model_name = 'DCN'
print(f"running {model_name}...")
start = time.time()
result = run(model_name)
t = time.time() - start
print(f"It took {t/60:.2f} mins")
print(result)
# wandb.run.finish()

# %% [markdown]
# # inference

# %%
model_path='/opt/ml/input/Recbole/saved/MultiVAE-Jun-04-2023_12-03-05.pth'
# rank K 설정
K = 10

# %%
# config, model, dataset 불러오기
checkpoint = torch.load(model_path)
config = checkpoint['config']
config['dataset'] = 'train_data'

dataset = create_dataset(config)
train_data, valid_data, test_data = data_preparation(config, dataset)

model = get_model(config['model'])(config, test_data.dataset).to(config['device'])
model.load_state_dict(checkpoint['state_dict'])
model.load_other_parameter(checkpoint.get('other_parameter'))

# device 설정
device = config.final_config_dict['device']

# user, item id -> token 변환 array
user_id = config['USER_ID_FIELD']
item_id = config['ITEM_ID_FIELD']
user_id2token = dataset.field2id_token[user_id]
item_id2token = dataset.field2id_token[item_id]

# user id list
all_user_list = torch.arange(1, len(user_id2token)).view(-1,128)

# user, item 길이
user_len = len(user_id2token)
item_len = len(item_id2token)

# user-item sparse matrix
matrix = dataset.inter_matrix(form='csr')

# user id, predict item id 저장 변수
pred_list = None
user_list = None

# model 평가모드 전환
model.eval()

# progress bar 설정
tbar = tqdm(all_user_list, desc=set_color(f"Inference", 'pink'))

for data in tbar:
    # interaction 생성
    interaction = dict()
    interaction = Interaction(interaction)
    interaction[user_id] = data
    interaction = interaction.to(device)

    # user item별 score 예측
    score = model.full_sort_predict(interaction)
    score = score.view(-1, item_len)

    rating_pred = score.cpu().data.numpy().copy()

    user_index = data.numpy()

    idx = matrix[user_index].toarray() > 0

    rating_pred[idx] = -np.inf
    rating_pred[:, 0] = -np.inf
    ind = np.argpartition(rating_pred, -K)[:, -K:]

    arr_ind = rating_pred[np.arange(len(rating_pred))[:, None], ind]

    arr_ind_argsort = np.argsort(arr_ind)[np.arange(len(rating_pred)), ::-1]

    batch_pred_list = ind[
        np.arange(len(rating_pred))[:, None], arr_ind_argsort
    ]

    if pred_list is None:
        pred_list = batch_pred_list
        user_list = user_index
    else:
        pred_list = np.append(pred_list, batch_pred_list, axis=0)
        user_list = np.append(
            user_list, user_index, axis=0
        )

result = []
for user, pred in zip(user_list, pred_list):
    for item in pred:
        result.append((int(user_id2token[user]), int(item_id2token[item])))

# # 데이터 저장
# sub = pd.DataFrame(result, columns=["user", "item"])
# sub.to_csv(
#     "submission.csv", index=False
)
print('inference done!')

# %%
sub

# %%
sub.user = sub.user.map(uidx2user)
sub.item = sub.item.map(iidx2item)

# %% [markdown]
# # 추천 결과 10개

# %%
# SAVE OUTPUT
output_dir = '/opt/ml/input/Recbole/output/'
write_path = os.path.join(output_dir, "MultiVAE.csv")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
with open(write_path, 'w', encoding='utf8') as w:
    print("writing prediction : {}".format(write_path))
    w.write("user,item\n")
    for id, p in sub.values:
        w.write('{},{}\n'.format(id,p))

# %%
sub / 0.06/ 0.13
